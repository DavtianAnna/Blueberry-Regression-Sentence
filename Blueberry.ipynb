# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.drop('id', axis = 1, inplace = True)
df_test.drop('id', axis = 1, inplace = True)

# %% [markdown]
# # SGDRegressor + StandardScaler + Pipeline

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop('yield', axis = 1)
X_test = df_test.copy()
y_train = df_train['yield']

# %%
scaler = StandardScaler()

# %%
model = SGDRegressor()

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
params = {
    'model__penalty': ['l2', 'l1', 'elasticnet', None],
    'model__alpha': [0.001, 0.01, 0.1,],
    'model__max_iter': [10, 100, 1000],
    'model__eta0': [0.001, 0.01, 0.1,]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
final_model = GridSearchCV(pipe, param_grid=params, cv=3, n_jobs=-1)

# %%
final_model.fit(X_train, y_train)

# %%
final_model.best_params_

# %%
final_model.best_score_

# %%
y_pred = final_model.predict(X_val)

# %%
mean_absolute_error(y_val,y_pred)

# %%
np.sqrt(mean_squared_error(y_pred, y_val))

# %%
finaly_y = final_model.predict(X_test)
df_sub = pd.read_csv('sample_submission.csv')
df_sub['yield'] = finaly_y
df_sub.to_csv('sub.csv',  index = False, index_label=False)

# %%
df_sub

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
X_train = df_train.drop('yield', axis = 1)
X_test = df_test.copy()
y_train = df_train['yield']

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor()

# %%
params = {
    'n_estimators': [100, 150],
    'criterion': ["squared_error","absolute_error"],
    'max_depth': [2, 4, None]
}

# %%
final_model = GridSearchCV(model, param_grid=params, cv=3, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END criterion=squared_error, max_depth=2, n_estimators=100; total time=   1.4s
# [CV] END criterion=squared_error, max_depth=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=squared_error, max_depth=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=squared_error, max_depth=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=squared_error, max_depth=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=squared_error, max_depth=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=100; total time=   2.2s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=100; total time=   2.1s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=100; total time=   2.1s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=150; total time=   3.1s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=150; total time=   3.1s
# [CV] END criterion=squared_error, max_depth=4, n_estimators=150; total time=   3.1s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=100; total time=  10.9s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=100; total time=  11.0s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=100; total time=  11.0s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=150; total time=  16.7s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=150; total time=  16.3s
# [CV] END criterion=squared_error, max_depth=None, n_estimators=150; total time=  16.8s
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=100; total time= 2.4min
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=100; total time= 2.4min
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=100; total time= 2.4min
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=150; total time= 3.6min
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=150; total time= 3.6min
# [CV] END criterion=absolute_error, max_depth=2, n_estimators=150; total time= 3.6min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=100; total time= 3.1min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=100; total time= 3.2min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=100; total time= 3.4min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=150; total time= 4.7min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=150; total time= 4.8min
# [CV] END criterion=absolute_error, max_depth=4, n_estimators=150; total time= 4.8min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=100; total time= 4.4min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=100; total time= 4.4min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=100; total time= 4.4min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=150; total time= 6.3min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=150; total time= 6.1min
# [CV] END criterion=absolute_error, max_depth=None, n_estimators=150; total time= 6.1min
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [2, 4, None],
#                          'n_estimators': [100, 150]},
#              verbose=2)

# %%
y_pred = final_model.predict(X_val)

# %%
mean_absolute_error(y_val,y_pred)
# Out:
# 257.7831711332445

# %%
np.sqrt(mean_squared_error(y_pred, y_val))
# Out:
# np.float64(374.7373801082046)

# %%
finaly_y = final_model.predict(X_test)
df_sub = pd.read_csv('sample_submission.csv')
df_sub['yield'] = finaly_y
df_sub.to_csv('sub1.csv',  index = False, index_label=False)

# %% [markdown]
# # XGBRegressor + GridSearchCV

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
X_train = df_train.drop('yield', axis = 1)
X_test = df_test.copy()
y_train = df_train['yield']

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
model = XGBRegressor()

# %%
params = {
    'n_estimators': [50, 100, 150, 200],
}

# %%
final_model = GridSearchCV(model, param_grid=params, cv=3)

# %%
final_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'n_estimators': [50, 100, 150, 200]})

# %%
y_pred = final_model.predict(X_val)

# %%
np.sqrt(mean_squared_error(y_pred, y_val))
# Out:
# np.float64(373.27019201715285)

# %%
mean_absolute_error(y_val,y_pred)
# Out:
# 257.4069602624479

# %%
finaly_y = final_model.predict(X_test)
df_sub = pd.read_csv('sample_submission.csv')
df_sub['yield'] = finaly_y
df_sub.to_csv('sub2.csv',  index = False, index_label=False)
